# %% [markdown]
# ## 06. **Hypothesis test**
#  - Author: Santiago Trejo
#  - Date: 18/08/2025
#  - Goal: Aprender a hacer predicciones en base a los datos que tenemos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# Ha quedado bien establecido por los cientificos medicos que si el contenido medio de nicotina de los cigarrillos es de 35mg o mas, es probable que el fumador contraiga cancer. Si el contenido de nicotina medio es menor a 25mg, el usuario se encuentra relativamente seguro.
#
# Para establecer la hipotesis nuestro interes es muestrear una cantidad de cigarrillos y ver si el promedio de esta muestra es mayor a 25.
#
# H_0 : $\mu >= 25$
# H_1 : $\mu < 25$

# %% [markdown]
# -----------------------

# %% [markdown]
# Un proceso industrial usado por una fabrica durante algunos años da una produccion media de 100 unidades por hora, con una desviacion estandar de 8 unidades. Acaba de ponerse en el mercado una nueva maquina para producir el mismo producto. Aunque es muy costosa comparada con la que actualmente tenemos, su adopcion seria muy lucrativa si su produccion media fuera mayor a 150 unidades por hora. Suponga que la nueva maquina ha sido probada 35 horas y se ha encontrado que el promedio de produccion es de 160 unidades por hora. Explicar su decision con respecto a la compra de la nueva maquina.
#
# H_0 : $\mu <= 150$
# H_1 : $\mu >= 150$
#
# $Media (\bar{x}) : 160$
# $Desviacion estandar (\sigma): 8$
# $Tamañp muestra (n) : 35$
#
# $z = \frac{\bar{x} - \mu_0}{\sigma/\sqrt{n}}$
#
# esadistico (z) = (promedio de la muestra - promedio de nuestra hipotesis) / (desviacion estandar de la muestra / raiz cuadrada de cantidad de muestras)

# %%
def decision(value:float) -> float:
    if p_value < alpha:
        return print("Nos quemos con nuestra hipotesis alternativa (H_1)")
    else:
        return print("Nos quedamos con unestra hipotesis nula (H_0)")
n = 35
sample_mean = 160
poblational_mean = 150
poblational_std = 8
alpha = 0.05 #Estamos dispuestos a aceptar un error del 5% (1-alfa es lo que estamos dispuesto a estar en lo correcto)

z_score = (sample_mean - poblational_mean) / (poblational_std / np.sqrt(n) )
p_value = 1 - stats.norm.cdf(abs(z_score))

#Si p_value < alpha, entonces queda H_1. Si no queda H_0
decision(p_value)
# Out:
# Nos quemos con nuestra hipotesis alternativa (H_1)

# %% [markdown]
# La distancia media que debe recorrer un automovil de cierta marca para detenerse cuando marcha a 30 millas por hora es 65 pies. El departamento de ingenieria de la compañia ha diseñado un nuevo sistema de frenos considerado como mas eficaz. Para probar esta invencion el nuevo sistema de frenos es instalado en 64 autos; las pruebas demuestran que la distancia media para detener un automovil a una velocidad de 30 millas por hora es de 63.5 pies, con una desviacion estandar de 4 pies. Esta reduccion de distancia ¿ Demuestra que este sistema de frenos es mas eficiente que el antiguo ?
#
# H_0 : $\mu >= 65$
# H_1 : $\mu < 65$  (Es lo que queremos probar)
# Nivel de isgnificancia ($\alpha$) : $0.01$
#
# $Media (\bar{x}) : 63.5$
# $Desviacion-estandar (\sigma): 4$
# $Tamaño-muestra (n) : 64$
#
# $z = \frac{\bar{x} - \mu_0}{\sigma/\sqrt{n}}$
#
# esadistico (z) = (promedio de la muestra - promedio de nuestra hipotesis) / (desviacion estandar de la muestra / raiz cuadrada de cantidad de muestras)

# %%
def decision(value:float, alp:float) -> float:
    if p_value < alp:
        return print(f"Nos quemos con nuestra hipotesis alternativa (H_1): {value} < {alp}")
    else:
        return print(f"Nos quemos con nuestra hipotesis alternativa (H_0): {value} > {alp}")
n = 64
sample_mean = 63.5
poblational_mean = 65
poblational_std = 4
alpha = 0.01 #Estamos dispuestos a aceptar un error del 1% (1-alfa es lo que estamos dispuesto a estar en lo correcto)

z_score = (sample_mean - poblational_mean) / (poblational_std / np.sqrt(n) )
p_value = 1 - stats.norm.cdf(abs(z_score))

#Si p_value < alpha, entonces queda H_1. Si no queda H_0
decision(p_value,alpha)
# Out:
# Nos quemos con nuestra hipotesis alternativa (H_1): 0.0013498980316301035 < 0.01

# %% [markdown]
# Un fabricante de ceras para piso tiene vendedores en toda la nacion. En el pasado sus vendedores ganaban una comison promedio de 600$ mensuales, con una desviacion estandar de 80$. Recientemente, nuevas marcas de ceras para pisos han entrado al mercado, y este factor tiene a reducir el volumen de ventas por vendedor, y por lo tanto el ingreso de los vendedores. Suponga que se extrae al azar una muestra de 100 comisiones y se encuentra que el promedio es de 585$. La gerencia de la empresa esta ansiosa por descubrir si ha habido un efecto neto en las comisiones por la entrada de esta nueva marca.
#
# H_0 : $\mu = 600$
# H_1 : $\mu \neq 600$  (Es lo que queremos probar)
# Nivel de significancia ($\alpha$) : $0.05$
#
# $Media (\bar{x}) : 585$
# $Desviacion-estandar (\sigma): 80$
# $Tamaño-muestra (n) : 100$
#
# $z = \frac{\bar{x} - \mu_0}{\sigma/\sqrt{n}}$
#
# esadistico (z) = (promedio de la muestra - promedio de nuestra hipotesis) / (desviacion estandar de la muestra / raiz cuadrada de cantidad de muestras)

# %%
def decision(value:float, alp:float) -> float:
    if p_value < alp:
        return print(f"Nos quemos con nuestra hipotesis alternativa (H_1): {value} < {alp}")
    else:
        return print(f"Nos quemos con nuestra hipotesis alternativa (H_0): {value} > {alp}")

n = 100
sample_mean = 585 
poblational_mean = 600 
poblational_std = 80
alpha = 0.05/2 #Estamos dispuestos a aceptar un error del 1% (1-alfa es lo que estamos dispuesto a estar en lo correcto)

z_score = (sample_mean - poblational_mean) / (poblational_std / np.sqrt(n) )
p_value = 1 - stats.norm.cdf(abs(z_score))

#Si p_value < alpha, entonces queda H_1. Si no queda H_0
decision(p_value,alpha)
# Out:
# Nos quemos con nuestra hipotesis alternativa (H_0): 0.030396361765261393 > 0.025

# %% [markdown]
# ----------------------

# %%
url_2010 = "/workspaces/clases_4geeks/ACCIDENTS_GU_BCN_2010.csv"

# %%
df_raw_2010 = pd.read_csv(url_2010, encoding='latin1')
df_raw_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9056 entries, 0 to 9055
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Número d'expedient            9056 non-null   object
#  1   Codi districte                9056 non-null   int64
#  2   Nom districte                 9056 non-null   object
#  3   NK barri                      9056 non-null   object
#  4   Nom barri                     9056 non-null   object
#  5   Codi carrer                   9056 non-null   int64
#  6   Nom carrer                    9056 non-null   object
#  7   Num postal caption            9056 non-null   object
#  8   Descripció dia setmana        9056 non-null   object
#  9   Dia de setmana                9056 non-null   int64
#  10  Descripció tipus dia          9056 non-null   object
#  11  NK Any                        9056 non-null   int64
# ...

# %%
df_raw_2010.sample(10)
# Out:
#      Número d'expedient  Codi districte        Nom districte   NK barri  \
# 6549        2010S008435               3       Sants-Montjuïc    34-3-18
# 4549        2010S001106               9          Sant Andreu    92-9-60
# 6279        2010S005383              10           Sant Martí  105-10-66
# 2214        2010S007558               8           Nou Barris    84-8-45
# 6419        2010S002997               2             Eixample     24-2-7
# 5771        2010S008332               2             Eixample     22-2-9
# 6218        2010S003763               9          Sant Andreu    92-9-60
# 3217        2010S004270               5  Sarrià-Sant Gervasi    52-5-23
# 1810        2010S009039               2             Eixample     24-2-7
# 6837        2010S001624              10           Sant Martí  101-10-65
#
#                               Nom barri  Codi carrer       Nom carrer  \
# 6549                              Sants       312400            Sants
# ...

# %%
#Step 2 Preprocessing
df_baking_2010 = df_raw_2010.copy()
df_baking_2010["date"] = df_baking_2010['Dia de mes'].apply(lambda x: str(x)) + '-' + df_baking_2010['Mes de any'].apply(lambda x: str(x))
data = df_baking_2010["date"].value_counts()

# %%
data.value_counts().mean() #Accidentes en promedio en barcelona es de 8.90 diarios
# Out:
# np.float64(8.902439024390244)

# %%
data.value_counts().std() #Desviacion estandar 6.264203373330006 hay mucha variabilidad porque es mas de la mitad de la media
# Out:
# np.float64(6.264203373330006)

# %% [markdown]
# La ciudad de barcelona está verificando la efectividad de sus politicas de seguridad vial. Luego de tomar una muestra de 30 dias observó que los accidentes fueron de 8.02 en promedio. ¿Podemos considerar que las politicas de seguridad han tenido efecto ?

# %% [markdown]
# H_0 : $\mu = 8.902$
# H_1 : $\mu \neq 8.902$  (Es lo que queremos probar)
# Nivel de significancia ($\alpha$) : $0.05$
#
# $Media (\bar{x}) : 8.02$
# $Desviacion-estandar (\sigma): 6.264$
# $Tamaño-muestra (n) : 30$
#
# $z = \frac{\bar{x} - \mu_0}{\sigma/\sqrt{n}}$
#
# esadistico (z) = (promedio de la muestra - promedio de nuestra hipotesis) / (desviacion estandar de la muestra / raiz cuadrada de cantidad de muestras)

# %%
def decision(value:float, alp:float) -> float:
    if p_value < alp:
        return print(f"Nos quemos con nuestra hipotesis alternativa (H_1): {value} < {alp}")
    else:
        return print(f"Nos quemos con nuestra hipotesis alternativa (H_0): {value} > {alp}")

n = 30
sample_mean = 8.02 
poblational_mean = 8.902 
poblational_std = 6.264
alpha = 0.05/2 #Estamos dispuestos a aceptar un error del 1% (1-alfa es lo que estamos dispuesto a estar en lo correcto)

z_score = (sample_mean - poblational_mean) / (poblational_std / np.sqrt(n) )
p_value = 1 - stats.norm.cdf(abs(z_score))

#Si p_value < alpha, entonces queda H_1. Si no queda H_0
decision(p_value,alpha)
# Out:
# Nos quemos con nuestra hipotesis alternativa (H_0): 0.2202887022878277 > 0.025

# %% [markdown]
# El distrito de barcelona no puede decir a ciencia cierta que las politicas de reduccion de accidentes viales ha tenido efecto debido a la gran varianza que hay
